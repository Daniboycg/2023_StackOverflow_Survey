# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows',50)
pd.set_option('display.max_columns',50)
pd.options.display.float_format='{:,.2f}'.format
import sys
sys.path.append('..')
from utility import plot_settings
df = pd.read_pickle('../../data/processed/YearlySalary_model_p2.pkl')
df.head()
# Out:
#                Age             CurrentJob  \
# 0  25-34 years old   Developer, front-end
# 1  25-34 years old  Developer, full-stack
# 2  35-44 years old    Developer, back-end
# 3  35-44 years old  Developer, full-stack
# 4  25-34 years old  Developer, full-stack
#
#                                              EdLevel            Industry  \
# 0       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       Not_Responded
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)               Other
# 2  Some college/university study without earning ...               Other
# 3  Some college/university study without earning ...          Technology
# 4       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Financial Services
#
#                              RemoteWork  YearlySalary  YearsCode  \
# 0  Hybrid (some remote, some in-person)    156,000.00      12.00
# 1                                Remote     23,456.00       6.00
# 2                                Remote     96,828.00      21.00
# 3                                Remote    135,000.00       4.00
# 4                                Remote     80,000.00       5.00
#
#    YearsCodePro  z_UsingAI  Developer         Region  MacOS  Linux  Windows  \
# 0          7.00          0          1  North America      1      0        0
# 1          4.00          1          1     South Asia      0      0        0
# 2         21.00          1          1         Europe      1      0        0
# 3          3.00          1          1  North America      1      0        0
# 4          3.00          1          1  North America      1      1        1
#
#    Other_OS  JavaScript  HTML/CSS  SQL  Python  TypeScript  \
# 0         0           1         1    1       0           1
# 1         1           1         1    0       0           1
# 2         0           1         1    1       0           1
# 3         0           1         1    0       0           1
# 4         0           1         1    1       1           1
#
#    Bash/Shell (all shells)  Ruby  Other_Language
# 0                        1     1               1
# 1                        0     0               0
# 2                        1     1               0
# 3                        0     1               1
# 4                        0     0               1

# %%
from sklearn.model_selection import train_test_split
X = df.drop('YearlySalary', axis=1)
y = df['YearlySalary']
X_train, X_, y_train, y_ = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
X_.head()
# Out:
#                    Age             CurrentJob  \
# 12512  18-24 years old  Developer, full-stack
# 43655  45-54 years old  Developer, full-stack
# 29154  45-54 years old    Engineering manager
# 19774  25-34 years old      DevOps specialist
# 8875   25-34 years old  Developer, full-stack
#
#                                                EdLevel            Industry  \
# 12512  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)          Technology
# 43655  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       Not_Responded
# 29154     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Financial Services
# 19774     Bachelor’s degree (B.A., B.S., B.Eng., etc.)               Other
# 8875   Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       Not_Responded
#
#                                  RemoteWork  YearsCode  YearsCodePro  \
# 12512                             In-person       3.00          0.00
# 43655                             In-person      40.00         15.00
# 29154  Hybrid (some remote, some in-person)      27.00         24.00
# 19774  Hybrid (some remote, some in-person)      20.00         17.00
# 8875                              In-person       6.00          5.00
#
#        z_UsingAI  Developer         Region  MacOS  Linux  Windows  Other_OS  \
# 12512          1          1     South Asia      0      0        1         0
# 43655          1          1  North America      1      0        0         1
# 29154          0          1         Europe      1      0        0         0
# 19774          0          1  North America      1      1        1         1
# 8875           0          1         Europe      1      1        0         1
#
#        JavaScript  HTML/CSS  SQL  Python  TypeScript  Bash/Shell (all shells)  \
# 12512           1         1    1       1           1                        0
# 43655           1         1    1       1           0                        0
# 29154           0         0    0       0           0                        0
# 19774           0         0    1       1           0                        1
# 8875            1         1    0       1           0                        0
#
#        Ruby  Other_Language
# 12512     1               1
# 43655     0               1
# 29154     0               1
# 19774     0               1
# 8875      1               1
