# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 30)
pd.options.display.float_format='{:,.2f}'.format
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
df = pd.read_pickle("../../data/interim/interest_SO_survey_2023.pkl")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87981 entries, 0 to 87980
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                87981 non-null  object
#  1   BuyNewTool         83009 non-null  object
#  2   Country            87973 non-null  object
#  3   CoursesCert        37076 non-null  object
#  4   CurrentJob         76872 non-null  object
#  5   EdLevel            87973 non-null  object
#  6   Employment         87898 non-null  object
#  7   Industry           36774 non-null  object
#  8   MainBranch         87981 non-null  object
#  9   OSPersonal         86557 non-null  object
#  10  OSProffesional     78587 non-null  object
#  11  ProfessionalTech   41783 non-null  object
#  12  RemoteWork         73810 non-null  object
#  13  TargetAIDeveloper  19587 non-null  object
#  14  TargetAISearch     46150 non-null  object
#  15  TargetCollabTools  76649 non-null  object
# ...

# %%
df.sample(5)
# Out:
#                    Age                                         BuyNewTool
# 20265  25-34 years old  Start a free trial;Ask developers I know/work ...  \
# 27847  25-34 years old  Ask developers I know/work with;Visit develope...
# 17505  25-34 years old  Ask developers I know/work with;Visit develope...
# 69651  25-34 years old  Start a free trial;Ask developers I know/work ...
# 20652  18-24 years old  Start a free trial;Ask developers I know/work ...
#
#                         Country CoursesCert                     CurrentJob
# 20265                    Turkey    Coursera    Developer, game or graphics  \
# 27847  United States of America       Udemy  Cloud infrastructure engineer
# 17505                    Poland         NaN            Developer, back-end
# 69651  United States of America         NaN          Developer, full-stack
# 20652                   Germany         NaN          Developer, full-stack
#
#                                                  EdLevel
# ...

# %% [markdown]
# I have my own dataset, with actual real data :D The quantity of things that I can do it's inimaginable.
# Having said this, what's my goal on this Notebook? There are some many columns to experiment

# %% [markdown]
# Okey. I have an idea of what I'm going to do n.n
# In this notebook, **I will create a function that shows me a graph with the top 5 things the people are using and want to use, as libraries, frameworks, platforms, language, etc.**
# I think It's easy if I ask it to ChatGPT, and although it is part of this new reality, I want to get the basic ML skills by my way.

# %%
def Top(column_name):

    column_name = column_name.str.split(';')
    df_exploded = column_name.explode()
    graph = df_exploded.value_counts().nlargest(5)
    sns.barplot(x=graph.index, y=graph, palette='inferno')
    plt.title(f'Top {len(graph)} {column_name.name} in 2023')
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Perfect! ( ;-; )

# %% [markdown]
# It's just as I was thinking the graph. Now, my purpose is, with list slicing and a loop, show the 9 target, and the 9 worked things. I think I can't stack them together because the values in x may be different. Anyway, I've done to much today. Tomorrow I will finish with this notebook.

# %%
for i in range (13,21):
    Top(df.iloc[:,i])

# %% [markdown]
# With a simple loop, I can visualize the 9 target things the programmers are loking for this 2023. :0 This is amazing. I was thinking: What would I do if the columns were not ordered? I could not do the graphs with list slicing, but I think there is not a big problem. I could create a new list selecting just the interest columns n.n

# %% [markdown]
# Maybe the output of the graphs are too long. How could I create a figure in matplotlib where I can show all of them? Tbh, I don't know, so I asked to ChatGPT. I will show you all of our talk:

# %% [markdown]
# Te explico mi problema detalladamente. Tengo una funcion:
# "import matplotlib.pyplot as plt
# import seaborn as sns
# plt.style.use('fivethirtyeight')
# def Top(column_name):
#
#     column_name = column_name.str.split(';')
#     df_exploded = column_name.explode()
#     graph = df_exploded.value_counts().nlargest(10)
#     sns.barplot(x=graph.index, y=graph, palette='viridis')
#     plt.title(f'Top {len(graph)} {column_name.name} in 2023')
#     plt.xticks(rotation=90)
#     plt.show()"
# A esta, yo simplemente le introduzco la columna que quiero, por ejemplo: "Top(df['TargetLanguage')", y esta me crea una grafica de dicha columna.
# la salida de las graficas, muestramelas en un lienzo de 3x3 con matplotlib

# %%
# # ChatGPT Response:
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Assuming you have a DataFrame named 'df' with the columns you want to visualize
# # columns_list contains the names of the 9 columns you want to visualize
# columns_list = ['TargetLanguage', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6', 'Column7', 'Column8', 'Column9']

# plt.style.use('fivethirtyeight')
# sns.set_palette('viridis')

# def Top(column_name, ax):
#     column_name = column_name.str.split(';')
#     df_exploded = column_name.explode()
#     graph = df_exploded.value_counts().nlargest(10)
#     sns.barplot(x=graph.index, y=graph, ax=ax)
#     ax.set_title(f'Top {len(graph)} {column_name.name} in 2023')
#     ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# # Create the 3x3 subplots
# fig, axs = plt.subplots(3, 3, figsize=(15, 15))

# # Loop through the columns_list and call the Top() function for each column
# for i, column in enumerate(columns_list):
#     row = i // 3
#     col = i % 3
#     Top(df[column], axs[row, col])

# # Adjust the layout to prevent overlapping titles
# plt.tight_layout()

# # Show the plots
# plt.show()
''' Just select the code and uncomment.
Anyways, I did not run it'''
'''My response: how would you rewrite the same code, with a better syntax'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame named 'df' with the columns you want to visualize
# columns_list contains the names of the 9 columns you want to visualize
Target_things = ['TargetAIDeveloper', 'TargetAISearch', 'TargetCollabTools', 'TargetDatabase', 'TargetFramework', 'TargetLanguage', 'TargetLibraries', 'TargetPlatform', 'TargetTools']

plt.style.use('fivethirtyeight')
sns.set_palette('viridis')

def plot_top(column_name, ax):
    df_exploded = column_name.str.split(';').explode()
    graph = df_exploded.value_counts().nlargest(5)
    sns.barplot(x=graph.index, y=graph, ax=ax)
    ax.set_title(f'Top {len(graph)} {column_name.name} in 2023')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# Create the 3x3 subplots
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

# Loop through the columns_list and call the plot_top() function for each column
for ax, column in zip(axs.flat, Target_things):
    plot_top(df[column], ax)

# Adjust the layout to prevent overlapping titles
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# <3 <3 <3

# %% [markdown]
# This is amazing!! Im very happy. That's what I was expecting from the begining.
# Now, with just a few lines of code, I can show in which things the programmers are actually working:

# %%
Worked_things = ['WorkedAIDeveloper', 'WorkedAISearch', 'WorkedCollabTools', 'WorkedDatabase', 'WorkedFramework', 'WorkedLanguage', 'WorkedLibraries', 'WorkedPlatform', 'WorkedTools']
fig, axs = plt.subplots(3, 3, figsize=(15, 15))
for ax, column in zip(axs.flat, Worked_things):
    plot_top(df[column], ax)

# Adjust the layout to prevent overlapping titles
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ### **Questions and comments we can ask ourselves regarding the graphs:**
# 1. The people are using and want to use ChatGPT and Github Copilot as as AI tools
# 2. VSCode is the best IDE. Very powerfull.
# 3. Why PostgreSQL is in the top of Relational Databases? I'm learning MySQL because the free best tutorial that I found, is the "SQL for begginers", by MOSH
# 4. I'm not interested in the top Frameworks actually
# 5. We can see that Python is still under Javascript and HTML/CSS. But the people are wanting to learn it! python is gonna surpass all others by the next year. It could be a good practice to see the top 5 Language over the years with the last's SO surveys. I will look it in another Notebook
# 6. What's .NET(5+)? All the other 4 Target libraries are from Data science! :O
# 7. I must learn AWS, but I think there is still not the time
# 8. And tools... I've heard a lot of Docker, but still don't know what is it. I use Homebrew on mac, and instead of pip, I use conda.
